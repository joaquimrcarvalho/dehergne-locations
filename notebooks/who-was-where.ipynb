# %% [markdown]
# # show people staying in a given place

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook()
tlnb.print_info()
# Out:
# WARNING:root:Reusing existing container amazing_mcnulty
# Timelink version: 1.1.25
# Project name: dehergne
# Project home: /Users/jrc/mhk-home/sources/dehergne
# Database type: sqlite
# Database name: dehergne
# Kleio image: timelinkserver/kleio-server
# Kleio server token: WOcMo...
# Kleio server URL: http://127.0.0.1:8094
# Kleio server home: /Users/jrc/mhk-home/sources/dehergne
# Kleio server container: amazing_mcnulty
# Kleio version requested: latest
# Kleio server version: 12.8.593 (2025-03-16 21:55:53)
# SQLite directory: /Users/jrc/mhk-home/sources/dehergne/database/sqlite
# Database version: 6ccf1ef385a6
# Call print_info(show_token=True) to show the Kleio Server token
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=dehergne, project_home=/Users/jrc/mhk-home/sources/dehergne, db_type=sqlite, db_name=dehergne, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# ### show person by id

# %%
id='deh-faustino-soares'
from timelink.api.models.person import Person

with tlnb.db.session() as session:
    # get Person with id
    p = session.get(Person, id)
    print(p)
# Out:
# n$Faustino Soares/m/id=deh-faustino-soares
#   ls$nacionalidade/Portugal/
#   ls$jesuita-estatuto/Padre/
#   ls$dehergne/795//obs=Soares, Faustino (port.) P. 795 N. Guarda, dioc. « Aegitanens. » (nom latin de Guarda), 18 janv. 1728. E. Lisbonne 10 juill. 1748, noviciat d'Arroios, pour la Chine (Lus. 49, 55). Emb. non prêtre pour la Chine 1755-1758 (W 2107 et p. 426), de la vice-province de Chine. En 1767, exilé en Italie (Lus. 49, 158v n° 466., Lus. 41, 98). V. Rome, 10 août 1767, pr. (Hisp. 34, 446).
#   ls$nascimento@wikidata/"https://www.wikidata.org/wiki/Q750594"%Guarda/1728-01-18
#   ls$nascimento/Guarda#@wikidata:Q750594/1728-01-18
#   ls$jesuita-entrada@wikidata/"https://www.wikidata.org/wiki/Q597"%Lisboa/1748-07-10
#   ls$jesuita-entrada/Lisboa#@wikidata:Q597%Lisboa, Arroios/1748-07-10
#   ls$wicky-viagem/?/1756-12-31#entre 1755 e 1758 (dia intermedio)
#   ls$estadia/Itália#@wikidata:Q38/1767#exilado
#   ls$estadia@wikidata/"https://www.wikidata.org/wiki/Q38"%Itália/1767
#   ls$jesuita-votos/4V/1767-08-10
#   ls$jesuita-votos-local@wikidata/"https://www.wikidata.org/wiki/Q220"%Roma/1767-08-10
#   ls$jesuita-votos-local/Roma#@wikidata:Q220/1767-08-10
#   ls$embarque/[Para a China]/>1755:<1758#entre 1755 e 1758, não padre
#   ls$wicky/2107/>1755:<1758#entre 1755 e 1758

# %%
import pandas as pd
from timelink.pandas import entities_with_attribute, display_group_attributes

# show 500 rows
pd.set_option('display.max_rows', 550)

# @wikidata:Q3558780
place = ["https://www.wikidata.org/wiki/Q3558780", "https://www.wikidata.org/wiki/Q190134"]


residents = entities_with_attribute(
    entity_type='person',
    show_elements=['id','name','groupname'],
    the_type='estadia@wikidata',
    the_value=place,
    more_attributes=['jesuita-entrada'],
    db=tlnb.db,
)
display_group_attributes(
    ids=residents.index.unique(),
    entity_type='person',
    header_elements=['id','name','groupname'],
    header_attributes=['jesuita-entrada'],
    include_attributes=['estadia','chegada','partida','jesuita-votos-local','morte',
                        ],
    sort_attributes=['the_date'],
    cmap_name='Pastel1',
    db=tlnb.db)
# Out:
# <style type="text/css">
# #T_14da2_row0_col0, #T_14da2_row0_col1, #T_14da2_row0_col2, #T_14da2_row0_col3, #T_14da2_row0_col4, #T_14da2_row0_col5, #T_14da2_row0_col6, #T_14da2_row0_col7, #T_14da2_row0_col8 {
#   background-color: #fbb4ae;
# }
# #T_14da2_row1_col0, #T_14da2_row1_col1, #T_14da2_row1_col2, #T_14da2_row1_col3, #T_14da2_row1_col4, #T_14da2_row1_col5, #T_14da2_row1_col6, #T_14da2_row1_col7, #T_14da2_row1_col8 {
#   background-color: #ccebc5;
# }
# #T_14da2_row2_col0, #T_14da2_row2_col1, #T_14da2_row2_col2, #T_14da2_row2_col3, #T_14da2_row2_col4, #T_14da2_row2_col5, #T_14da2_row2_col6, #T_14da2_row2_col7, #T_14da2_row2_col8 {
#   background-color: #fed9a6;
# }
# #T_14da2_row3_col0, #T_14da2_row3_col1, #T_14da2_row3_col2, #T_14da2_row3_col3, #T_14da2_row3_col4, #T_14da2_row3_col5, #T_14da2_row3_col6, #T_14da2_row3_col7, #T_14da2_row3_col8 {
#   background-color: #e5d8bd;
# }
# #T_14da2_row4_col0, #T_14da2_row4_col1, #T_14da2_row4_col2, #T_14da2_row4_col3, #T_14da2_row4_col4, #T_14da2_row4_col5, #T_14da2_row4_col6, #T_14da2_row4_col7, #T_14da2_row4_col8 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_14da2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14da2_level0_col0" class="col_heading level0 col0" >id_1</th>
#       <th id="T_14da2_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_14da2_level0_col2" class="col_heading level0 col2" >groupname</th>
#       <th id="T_14da2_level0_col3" class="col_heading level0 col3" >jesuita-entrada.type</th>
#       <th id="T_14da2_level0_col4" class="col_heading level0 col4" >jesuita-entrada</th>
#       <th id="T_14da2_level0_col5" class="col_heading level0 col5" >jesuita-entrada.date</th>
#       <th id="T_14da2_level0_col6" class="col_heading level0 col6" >jesuita-entrada.obs</th>
#       <th id="T_14da2_level0_col7" class="col_heading level0 col7" >jesuita-entrada.date.comment</th>
#       <th id="T_14da2_level0_col8" class="col_heading level0 col8" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14da2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14da2_row0_col0" class="data row0 col0" >deh-francisco-de-cordes</td>
#       <td id="T_14da2_row0_col1" class="data row0 col1" >Francisco Cordes</td>
#       <td id="T_14da2_row0_col2" class="data row0 col2" >n</td>
#       <td id="T_14da2_row0_col3" class="data row0 col3" >jesuita-entrada</td>
#       <td id="T_14da2_row0_col4" class="data row0 col4" >?</td>
#       <td id="T_14da2_row0_col5" class="data row0 col5" >17040921</td>
#       <td id="T_14da2_row0_col6" class="data row0 col6" ></td>
#       <td id="T_14da2_row0_col7" class="data row0 col7" >None</td>
#       <td id="T_14da2_row0_col8" class="data row0 col8" >deh-francisco-de-cordes</td>
#     </tr>
#     <tr>
#       <th id="T_14da2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
# #T_61e96_row24_col0, #T_61e96_row24_col1, #T_61e96_row24_col2, #T_61e96_row24_col3, #T_61e96_row24_col4, #T_61e96_row24_col5, #T_61e96_row24_col6, #T_61e96_row24_col7, #T_61e96_row30_col0, #T_61e96_row30_col1, #T_61e96_row30_col2, #T_61e96_row30_col3, #T_61e96_row30_col4, #T_61e96_row30_col5, #T_61e96_row30_col6, #T_61e96_row30_col7 {
#   background-color: #e5d8bd;
# }
# #T_61e96_row25_col0, #T_61e96_row25_col1, #T_61e96_row25_col2, #T_61e96_row25_col3, #T_61e96_row25_col4, #T_61e96_row25_col5, #T_61e96_row25_col6, #T_61e96_row25_col7, #T_61e96_row29_col0, #T_61e96_row29_col1, #T_61e96_row29_col2, #T_61e96_row29_col3, #T_61e96_row29_col4, #T_61e96_row29_col5, #T_61e96_row29_col6, #T_61e96_row29_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_61e96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61e96_level0_col0" class="col_heading level0 col0" >id_1</th>
#       <th id="T_61e96_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_61e96_level0_col2" class="col_heading level0 col2" >groupname</th>
#       <th id="T_61e96_level0_col3" class="col_heading level0 col3" >the_type</th>
#       <th id="T_61e96_level0_col4" class="col_heading level0 col4" >the_value</th>
#       <th id="T_61e96_level0_col5" class="col_heading level0 col5" >the_date</th>
#       <th id="T_61e96_level0_col6" class="col_heading level0 col6" >attr_obs</th>
#       <th id="T_61e96_level0_col7" class="col_heading level0 col7" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61e96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61e96_row0_col0" class="data row0 col0" >deh-manuel-de-carvalho</td>
#       <td id="T_61e96_row0_col1" class="data row0 col1" >Manuel de Carvalho</td>
#       <td id="T_61e96_row0_col2" class="data row0 col2" >n</td>
#       <td id="T_61e96_row0_col3" class="data row0 col3" >estadia</td>
#       <td id="T_61e96_row0_col4" class="data row0 col4" >China</td>
#       <td id="T_61e96_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_61e96_row0_col6" class="data row0 col6" ></td>
#       <td id="T_61e96_row0_col7" class="data row0 col7" >deh-manuel-de-carvalho</td>
#     </tr>
#     <tr>
#       <th id="T_61e96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61e96_row1_col0" class="data row1 col0" >deh-francisco-de-cordes</td>
#       <td id="T_61e96_row1_col1" class="data row1 col1" >Francisco Cordes</td>
#       <td id="T_61e96_row1_col2" class="data row1 col2" >n</td>
#       <td id="T_61e96_row1_col3" class="data row1 col3" >chegada</td>
#       <td id="T_61e96_row1_col4" class="data row1 col4" >Macau</td>
#       <td id="T_61e96_row1_col5" class="data row1 col5" >17160803</td>
#       <td id="T_61e96_row1_col6" class="data row1 col6" ></td>
#       <td id="T_61e96_row1_col7" class="data row1 col7" >deh-francisco-de-cordes</td>
#     </tr>
#     <tr>
#       <th id="T_61e96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61e96_row2_col0" class="data row2 col0" >deh-francisco-de-cordes</td>
#       <td id="T_61e96_row2_col1" class="data row2 col1" >Francisco Cordes</td>
#       <td id="T_61e96_row2_col2" class="data row2 col2" >n</td>
#       <td id="T_61e96_row2_col3" class="data row2 col3" >estadia</td>
#       <td id="T_61e96_row2_col4" class="data row2 col4" >Cantão</td>
#       <td id="T_61e96_row2_col5" class="data row2 col5" >17170000</td>
#       <td id="T_61e96_row2_col6" class="da
