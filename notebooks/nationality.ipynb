# %% [markdown]
# # Nationality / Nacionalidades
#
# Analyze the nationalities of individuals in the dataset.

# %% [markdown]
# ## Setup
#
# Create a TimelinkNotebook object.
#
# Note:
# * First time run takes a little time as the required Docker images are downloaded.
# * Timelink will default to using sqlite as the database, see [Receipts notebook for more control](1-receipts.ipynb)

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook()
tlnb.print_info(show_token=True)
# Out:
# WARNING:root:Reusing existing container elastic_allen
# Timelink version: 1.1.25
# Project name: dehergne
# Project home: /Users/jrc/mhk-home/sources/dehergne
# Database type: sqlite
# Database name: dehergne
# Kleio image: timelinkserver/kleio-server
# Kleio server token: kNUFYoTqbJpr4eBBJ99Jw5E1ulv5UY9d
# Kleio server URL: http://127.0.0.1:8088
# Kleio server home: /Users/jrc/mhk-home/sources/dehergne
# Kleio server container: elastic_allen
# Kleio version requested: latest
# Kleio server version: 12.8.593 (2025-03-16 21:55:53)
# SQLite directory: /Users/jrc/mhk-home/sources/dehergne/database/sqlite
# Database version: 6ccf1ef385a6
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=dehergne, project_home=/Users/jrc/mhk-home/sources/dehergne, db_type=sqlite, db_name=dehergne, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# ### Extensions for this notebook
# (to later migrate to timelink-py)

# %%
from datetime import datetime
import pandas as pd
from timelink.kleio.utilities import format_timelink_date, convert_timelink_date


def calc_age_at(date_birth, today):
    """Compute the number of years between two dates"""
    # return None if either argument is None
    if date_birth is None or today is None:
        return None
    # Ensure the dates are datetime objects
    if not isinstance(date_birth, datetime):
        date_birth = convert_timelink_date(date_birth)
    if not isinstance(today, datetime):
        today = convert_timelink_date(today)

    if date_birth is None or today is None:
        return None

    # Compute the difference in years
    difference_in_years = (today - date_birth).days / 365.25
    return int(difference_in_years)


print("testing")
print(format_timelink_date('00000000'))
print(format_timelink_date(None))
print(format_timelink_date('1582'))
print(format_timelink_date('158203'))
print(format_timelink_date('1582-03-02'))
print(format_timelink_date('15820302'))
print(calc_age_at('1980-01-01', '2020-01-01'))
print(calc_age_at('1980-01-01', 0))
# Out:
# testing
#
#
# 1582
# 1582-03
# 1582-03-02
# 1582-03-02
# 40
# None

# %% [markdown]
# ### Database status
#
# Count the number of rows in each table in the database.

# %%
tlnb.table_row_count_df()
# Out:
#                table  count
# 0               acts     29
# 1    alembic_version      1
# 2         aregisters      1
# 3         attributes  26742
# 4             blinks    200
# 5   class_attributes     70
# 6            classes     14
# 7           entities  32950
# 8        geoentities    359
# 9              goods      0
# 10        kleiofiles     59
# 11             links     99
# 12           objects      0
# 13           persons   2132
# 14         relations   3532
# 15         rentities    111
# 16      rgeoentities      0
# 17          robjects      0
# 18          rpersons     65
# 19           sources     30
# 20            syslog      0
# 21            syspar      0

# %% [markdown]
# ### Check the status of the files

# %% [markdown]
# Check the import status of the translated files
#
# * I: Imported
# * E: Imported with error
# * W: Imported with warnings no errors
# * N: Not imported
# * U: Translation updated need to reimport

# %%
kleio_files = tlnb.get_kleio_files()
# kleio_files.info()
kleio_files[["name","import_status","status","errors","warnings","imported","import_errors","import_warnings"]]
# Out:
#                            name import_status status  errors  warnings  \
# 0          dehergne-0-abrev.cli             I      V       0         0
# 1                dehergne-a.cli             I      V       0         0
# 2                dehergne-b.cli             I      V       0         0
# 3                dehergne-c.cli             I      V       0         0
# 4                dehergne-d.cli             I      V       0         0
# 5                dehergne-e.cli             I      V       0         0
# 6                dehergne-f.cli             I      V       0         0
# 7                dehergne-g.cli             I      V       0         0
# 8                dehergne-h.cli             I      V       0         0
# 9                dehergne-i.cli             I      V       0         0
# 10               dehergne-j.cli             I      V       0         0
# 11               dehergne-k.cli             I      V       0         0
# 12               dehergne-l.cli             I      V       0         0
# 13  dehergne-locations-1644.cli             I      V       0         0
# 14  dehergne-locations-1701.cli             I      V       0         0
# 15               dehergne-m.cli             I      V       0         0
# 16               dehergne-n.cli             I      V       0         0
# 17               dehergne-o.cli             I      V       0         0
# 18               dehergne-p.cli             I      V       0         0
# 19               dehergne-q.cli             I      V       0         0
# 20               dehergne-r.cli             I      V       0         0
# 21               dehergne-s.cli             I      V       0         0
# 22               dehergne-t.cli             I      V       0         0
# 23               dehergne-u.cli             I      V       0         0
# 24               dehergne-v.cli             I      V       0         0
# 25               dehergne-w.cli             I      V       0         0
# 26               dehergne-x.cli             I      V       0         0
# 27               dehergne-y.cli             I      V       0         0
# 28               dehergne-z.cli             I      V       0         0
#
#                      imported  import_errors  import_warnings
# 0  2025-05-10 03:50:53.702537              0                0
# 1  2025-05-10 03:51:01.352077              0                0
# 2  2025-05-10 03:51:10.480262              0                0
# 3  2025-05-10 03:51:23.126101              0                0
# 4  2025-05-10 03:51:28.685167              0                0
# 5  2025-05-10 03:51:30.219256              0                0
# 6  2025-05-10 03:51:38.361830              0                0
# 7  2025-05-10 03:51:46.453827              0                0
# 8  2025-05-10 03:51:49.364195              0                0
# 9  2025-05-10 03:51:51.033646              0                0
# 10 2025-05-10 03:51:52.925637              0                0
# 11 2025-05-10 03:51:55.605259              0                0
# 12 2025-05-10 03:52:04.426212              0                0
# 13 2025-05-10 03:52:08.337291              0                0
# 14 2025-05-10 03:52:11.503709              0                0
# 15 2025-05-10 03:52:22.271596              0                0
# 16 2025-05-10 03:52:25.728711              0                0
# 17 2025-05-10 03:52:27.498184              0                0
# 18 2025-05-10 03:52:36.583046              0                0
# 19 2025-05-10 03:52:37.927529              0                0
# 20 2025-05-10 03:52:49.094654              0                0
# 21 2025-05-10 03:53:04.253047              0                0
# 22 2025-05-10 03:53:16.393043              0                0
# 23 2025-05-10 03:53:17.790263              0                0
# 24 2025-05-10 03:53:29.675125              0                0
# 25 2025-05-10 03:53:31.994314              0                0
# 26 2025-05-10 03:53:37.600551              0                0
# 27 2025-05-10 03:53:39.672615              0                0
# 28 2025-05-10 03:53:42.392875              0                0

# %%
# %pip install pyuca openpyxl
# Out:
# .bash_profile RUN!
# Requirement already satisfied: pyuca in /Users/jrc/mhk-home/sources/dehergne/.venv/lib/python3.10/site-packages (1.2)
# Requirement already satisfied: openpyxl in /Users/jrc/mhk-home/sources/dehergne/.venv/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/jrc/mhk-home/sources/dehergne/.venv/lib/python3.10/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyuca  # to sort accented characters properly

import pandas as pd
from timelink.pandas import entities_with_attribute
# show 500 rows
pd.set_option('display.max_rows', 550)

nacionais = entities_with_attribute(
    entity_type='person',
    show_elements=['id','name','groupname'],
    the_type='nacionalidade',
    more_attributes=['nascimento'],
    db=tlnb.db,
)
# filter groupname = 'n' (avoid "referido", "pai", "mãe")
nacionais = nacionais[nacionais.groupname=='n']
nacionais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 943 entries, deh-abraham-le-royer to joao-cardoso
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_1                      943 non-null    object
#  1   name                      943 non-null    object
#  2   groupname                 943 non-null    object
#  3   nacionalidade.attr_id     943 non-null    object
#  4   nacionalidade.type        943 non-null    object
#  5   nacionalidade             943 non-null    object
#  6   nacionalidade.date        943 non-null    object
#  7   nacionalidade.line        943 non-null    int64
#  8   nacionalidade.level       943 non-null    int64
#  9   nacionalidade.obs         943 non-null    object
#  10  nacionalidade.extra_info  943 non-null    object
#  11  nacionalidade.original    1 non-null      object
#  12  nacionalidade.comment     34 non-null     object
#  13  nascimento                855 non-null    object
#  14  nascimento.date           855 non-null    object
#  15  nascimento.obs            855 non-null    object
#  16  nascimento.extra_info     855 non-null    object
#  17  nascimento.original       46 non-null     object
# dtypes: int64(2), object(16)
# memory usage: 140.0+ KB

# %% [markdown]
# ### Export all with attribute "nacionalidade"

# %%
nacionais.to_excel("../inferences/paises_pessoas_n.xlsx", sheet_name='Sheet1', index=False)

# %% [markdown]
# ### Group by nacionalidade

# %%
paises_totais=nacionais.groupby('nacionalidade')['id_1'].nunique().reset_index().sort_values('id_1',ascending=False)
paises_totais
# Out:
#    nacionalidade  id_1
# 19      Portugal   346
# 10        França   168
# 4          China   146
# 14        Itália   113
# 0       Alemanha    35
# 7        Espanha    34
# 3        Bélgica    22
# 24       Áustria    14
# 9       Flandres    11
# 2         Boémia    10
# 18       Polónia     8
# 23       Tonquim     5
# 11       Holanda     5
# 21         Suíça     5
# 15         Japão     5
# 22         Tirol     3
# 8         Europa     2
# 1        Alsácia     2
# 20        Sabóia     2
# 16      Lituânia     1
# 17        México     1
# 5         Coreia     1
# 13       Irlanda     1
# 6       Dalmácia     1
# 12    Inglaterra     1

# %%
paises_totais.to_excel("../inferences/paises_totais_n.xlsx", sheet_name='Sheet1', index=False)

# %% [markdown]
# ### Countries and evolution of departures

# %%
import pandas as pd
from timelink.pandas import entities_with_attribute
# show 500 rows
pd.set_option('display.max_rows', 550)

embarques = entities_with_attribute(
    entity_type='person',
    show_elements=['id','name','groupname'],
    the_type='nacionalidade',
    more_attributes=['wicky'],
    db=tlnb.db,
)
# filter groupname = 'n' (avoid "referido", "pai", "mãe")
embarques = embarques[embarques.groupname=='n']
embarques['wicky.date'] = embarques['wicky.date'].fillna('0000')
embarques.info()
cols =['name','nacionalidade','wicky.date']
# replace NaN in wicky.date with 0000

embarques[cols].sort_values('wicky.date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 973 entries, deh-abraham-le-royer to joao-cardoso
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_1                      973 non-null    object
#  1   name                      973 non-null    object
#  2   groupname                 973 non-null    object
#  3   nacionalidade.attr_id     973 non-null    object
#  4   nacionalidade.type        973 non-null    object
#  5   nacionalidade             973 non-null    object
#  6   nacionalidade.date        973 non-null    object
#  7   nacionalidade.line        973 non-null    int64
#  8   nacionalidade.level       973 non-null    int64
#  9   nacionalidade.obs         973 non-null    object
#  10  nacionalidade.extra_info  973 non-null    object
#  11  nacionalidade.original    1 non-null      object
#  12  nacionalidade.comment     35 non-null     object
#  13  wicky                     515 non-null    object
#  14  wicky.date                973 non-null    object
#  15  wicky.obs                 515 non-null    object
#  16  wicky.extra_info          515 non-null    object
#  17  wicky.original            3 non-null      object
#  18  wicky.date.original       3 non-null      object
# dtypes: int64(2), object(17)
# memory usage: 152.0+ KB
#                                                 name nacionalidade  \
# id
# deh-abraham-le-royer                Abraham Le Royer        França
# deh-joao-da-fonseca-i                João da Fonseca      Portugal
# deh-joao-da-silva                      João da Silva      Portugal
# deh-joao-de-borgia-kouo          João de Borgia Kouo      Portugal
# deh-joao-de-sa                            João de Sá      Portugal
# ...                                              ...           ...
# deh-francisco-pinto-ii               Francisco Pinto      Portugal
# deh-faustino-soares                  Faustino Soares      Portugal
# deh-sebastiao-correa                Sebastião Correa      Portugal
# deh-aleixo-rodrigues                Aleixo Rodrigues      Portugal
# deh-manuel-jose-de-carvalho  Manuel José de Carvalho      Portugal
#
#                               wicky.date
# id
# deh-abraham-le-royer                0000
# deh-joao-da-fonseca-i               0000
# deh-joao-da-silva                   0000
# deh-joao-de-borgia-kouo             0000
# deh-joao-de-sa                      0000
# ...                                  ...
# deh-francisco-pinto-ii       >1755:<1758
# deh-faustino-soares          >1755:<1758
# deh-sebastiao-correa         >1755:<1758
# deh-aleixo-rodrigues         >1755:<1758
# deh-manuel-jose-de-carvalho  >1755:<1758
#
# [973 rows x 3 columns]

# %% [markdown]
# #### Group by country decade

# %%
import pandas as pd
from timelink.kleio.utilities import convert_timelink_date

# extract the year from wicky.date
embarques['data_embarque'] = embarques['wicky.date'].apply(convert_timelink_date)
embarques['data_embarque'] = embarques['data_embarque'].fillna('0000-01-01')
embarques['ano_embarque'] = pd.to_datetime(embarques['data_embarque'], format='%Y-%m-%d', errors='coerce').dt.year
# count ano_entrada per periods of 10 years starting from 1540
embarques['periodo_embarque'] = embarques['ano_embarque'] // 10 * 10
# show columns jesuita-entrada.date, ano_entrada, periodo
embarques[['wicky.date','ano_embarque','periodo_embarque']].sort_values('wicky.date').tail(10)
# count number of embarques per period
embarques.groupby(['nacionalidade','periodo_embarque',])['id_1'].count().reset_index().sort_values(['nacionalidade','periodo_embarque',])
# Out:
#    nacionalidade  periodo_embarque  id_1
# 0       Alemanha            1680.0     2
# 1       Alemanha            1690.0     6
# 2       Alemanha            1700.0     3
# 3       Alemanha            1710.0     4
# 4       Alemanha            1730.0     5
# 5       Alemanha            1740.0     1
# 6       Alemanha            1750.0     1
# 7        Alsácia            1700.0     1
# 8         Boémia            1700.0     1
# 9         Boémia            1710.0     1
# 10        Boémia            1730.0     3
# 11        Boémia            1740.0     1
# 12       Bélgica            1680.0     3
# 13       Bélgica            1690.0     2
# 14       Bélgica            1700.0     1
# 15         China            1690.0     1
# 16         China            1710.0     1
# 17       Espanha            1680.0     2
# 18      Flandres            1680.0     1
# 19        França            1690.0     2
# 20       Holanda            1690.0     1
# 21        Itália            1690.0    19
# 22        Itália            1700.0     2
# 23        Itália            1710.0     8
# 24        Itália            1720.0     2
# 25        Itália            1730.0     1
# 26        Itália            1740.0     1
# 27       Polónia            1700.0     1
# 28      Portugal            1680.0    15
# 29      Portugal            1690.0    44
# 30      Portugal            1700.0     9
# 31      Portugal            1710.0    19
# 32      Portugal            1720.0     8
# 33      Portugal            1730.0    15
# 34      Portugal            1740.0    19
# 35      Portugal            1750.0    24
# 36        Sabóia            1680.0     1
# 37         Suíça            1690.0     1
# 38         Suíça            1700.0     1
# 39         Tirol            1730.0     1
# 40       Áustria            1700.0     2
# 41       Áustria            1710.0     1
# 42       Áustria            1730.0     3
# 43       Áustria            1740.0     1
